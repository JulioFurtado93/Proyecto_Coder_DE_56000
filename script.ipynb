# %% [markdown]
# Conexion a la API

# %%
import requests
import json
import pandas as pd

url = 'https://tradestie.com/api/v1/apps/reddit'
headers = {"Accept-Encoding": "gzip, deflate"}

response = requests.get(url, headers=headers)
data = response.json()
data
# Out:
# [{'no_of_comments': 53,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.033,
#   'ticker': 'AMC'},
#  {'no_of_comments': 27,
#   'sentiment': 'Bearish',
#   'sentiment_score': -0.024,
#   'ticker': 'TSLA'},
#  {'no_of_comments': 26,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.116,
#   'ticker': 'AI'},
#  {'no_of_comments': 24,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.06,
#   'ticker': 'NVDA'},
#  {'no_of_comments': 21,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.046,
#   'ticker': 'JPM'},
#  {'no_of_comments': 20,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.104,
#   'ticker': 'QQQ'},
#  {'no_of_comments': 13,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.028,
#   'ticker': 'LLY'},
#  {'no_of_comments': 12,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.1,
#   'ticker': 'LMT'},
#  {'no_of_comments': 12,
#   'sentiment': 'Bullish',
#   'sentiment_score': 0.112,
#   'ticker': 'NFLX'},
#  {'no_of_comments': 10,
# ...

# %%
data[0]
# Out:
# {'no_of_comments': 53,
#  'sentiment': 'Bullish',
#  'sentiment_score': 0.033,
#  'ticker': 'AMC'}

# %%
type(data)
# Out:
# list

# %%
data[0].keys()
# Out:
# dict_keys(['no_of_comments', 'sentiment', 'sentiment_score', 'ticker'])

# %%
reddit_sentiment = pd.DataFrame(data=data)
reddit_sentiment
# Out:
#     no_of_comments sentiment  sentiment_score ticker
# 0               53   Bullish            0.033    AMC
# 1               27   Bearish           -0.024   TSLA
# 2               26   Bullish            0.116     AI
# 3               24   Bullish            0.060   NVDA
# 4               21   Bullish            0.046    JPM
# 5               20   Bullish            0.104    QQQ
# 6               13   Bullish            0.028    LLY
# 7               12   Bullish            0.100    LMT
# 8               12   Bullish            0.112   NFLX
# 9               10   Bullish            0.236    IRS
# 10              10   Bullish            0.150   SQQQ
# 11               9   Bullish            0.158   MSFT
# 12               8   Bearish           -0.323     AA
# 13               7   Bullish            0.184   PYPL
# 14               6   Bearish           -0.228     ON
# 15               5   Bullish            0.192    TLT
# 16               5   Bullish            0.264     UK
# ...

# %% [markdown]
# Conexion a la base de datos

# %%
import psycopg2
